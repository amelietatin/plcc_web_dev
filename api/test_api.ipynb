# %%
import requests
import pandas as pd

# %%
url_base='https://landcoverapi-f37abimraq-ew.a.run.app/'
response = requests.get(url=url_base+'/data').json()
response
# Out:
# [{'Unnamed: 0': 201,
#   'SITECODE': 'FI1101617',
#   'quarter_start': '2015-07-01',
#   'Bare Ground': 0.0,
#   'Built Area': 0.0,
#   'Crops': 0.1853796903705794,
#   'Flooded Vegetation': 0.513231113904288,
#   'Grass': 2.6814185105074886,
#   'Shrub and Scrub': 8.616670079639881,
#   'Snow and Ice': 0.0,
#   'Trees': 84.82673568214308,
#   'Water': 3.047443081814853,
#   'temperature_quarterly_mean': 11.5,
#   'precipitation_quarterly_mean': 3.2553896e-08,
#   'water-vapor-pressure_quarterly_mean': 827.9851,
#   'cloud-cover_quarterly_mean': 0.765403},
#  {'Unnamed: 0': 202,
#   'SITECODE': 'FI1101620',
#   'quarter_start': '2015-07-01',
#   'Bare Ground': 0.0,
#   'Built Area': 0.0,
#   'Crops': 0.0098530827938948,
#   'Flooded Vegetation': 0.1455191919296798,
#   'Grass': 0.9972111934258938,
#   'Shrub and Scrub': 7.518704668706279,
#   'Snow and Ice': 0.0,
#   'Trees': 86.59485392275549,
#   'Water': 4.59715340207015,
#   'temperature_quarterly_mean': 11.5,
# ...

# %%
df = pd.DataFrame(response)

# %%
df
# Out:
#     Unnamed: 0   SITECODE quarter_start  Bare Ground  Built Area      Crops  \
# 0          201  FI1101617    2015-07-01     0.000000    0.000000   0.185380
# 1          202  FI1101620    2015-07-01     0.000000    0.000000   0.009853
# 2          204  FI1101630    2015-07-01     0.000000    0.000000   0.090353
# 3          174  FI0800018    2015-07-01     0.000000    0.000000   0.007267
# 4          167  FI0200075    2015-07-01     0.010435    0.000580   0.003042
# ..         ...        ...           ...          ...         ...        ...
# 95         343  IT51A0016    2015-07-01     0.009572    0.295038   2.873328
# 96         344  IT51A0021    2015-07-01     6.874958    1.645629  57.978823
# 97         400  ITA020010    2015-07-01     0.413190    7.800668   7.493701
# 98         156  ES6170015    2015-07-01    15.692022    0.482380  78.655089
# 99         158  ES6180003    2015-07-01    30.491965    0.336040  62.304973
#
# ...

# %%
url_local='http://localhost:8000'
params = {'item_id' : 'AT1301000'}
response2 = requests.get(url=url_local+'/data', params=params).json()

# %%
df = pd.DataFrame(response2)
df
# Out:
#     Unnamed: 0   SITECODE quarter_start  Bare Ground  Built Area      Crops  \
# 0          201  FI1101617    2015-07-01     0.000000    0.000000   0.185380
# 1          202  FI1101620    2015-07-01     0.000000    0.000000   0.009853
# 2          204  FI1101630    2015-07-01     0.000000    0.000000   0.090353
# 3          174  FI0800018    2015-07-01     0.000000    0.000000   0.007267
# 4          167  FI0200075    2015-07-01     0.010435    0.000580   0.003042
# ..         ...        ...           ...          ...         ...        ...
# 95         343  IT51A0016    2015-07-01     0.009572    0.295038   2.873328
# 96         344  IT51A0021    2015-07-01     6.874958    1.645629  57.978823
# 97         400  ITA020010    2015-07-01     0.413190    7.800668   7.493701
# 98         156  ES6170015    2015-07-01    15.692022    0.482380  78.655089
# 99         158  ES6180003    2015-07-01    30.491965    0.336040  62.304973
#
# ...
